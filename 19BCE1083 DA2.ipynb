# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ethusdt_kline_1m.csv")
df
# Out:
#                     t        o        h        l        c           v
# 0       1609430400000   736.00   736.97   735.74   735.85  1376.74470
# 1       1609430460000   735.75   735.93   733.60   733.79  1152.24573
# 2       1609430520000   733.84   734.47   732.45   732.55  1453.18100
# 3       1609430580000   732.55   733.41   732.47   732.65   667.83054
# 4       1609430640000   732.66   733.64   732.16   733.25   621.82394
# ...               ...      ...      ...      ...      ...         ...
# 484282  1638546900000  4469.50  4470.39  4459.05  4460.72  1065.35540
# 484283  1638546960000  4460.73  4467.33  4456.41  4461.91   618.26580
# 484284  1638547020000  4461.90  4473.39  4461.89  4467.51   395.76480
# 484285  1638547080000  4467.67  4472.83  4467.13  4470.90   403.78040
# 484286  1638547140000  4471.16  4476.71  4468.01  4468.15   534.88440
#
# [484287 rows x 6 columns]

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023828D54408>,
# ...
#       dtype=object)

# %%
df[:1000].plot.scatter(x = "t", y = 'o', s = 100);

# %%
df[:150].plot.bar(x="t",y="v",rot=0)

# %%
df[:150].plot.pie(y="h")

# %%
df[:1000].plot.line(x="t",y="c")
